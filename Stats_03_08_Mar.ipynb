# %% [markdown]
# ## Statistics Advance Assignment - 1
# ***By Shahequa Modabbera***

# %% [markdown]
# ### Q1. What is the Probability density function?

# %% [markdown]
# `Ans) In probability theory, a probability density function (PDF), or density of a continuous random variable, is a function whose value at any given sample (or point) in the sample space (the set of possible values taken by the random variable) can be interpreted as providing a relative likelihood that the value of the random variable would be equal to that sample.`

# %% [markdown]
# ### Q2. What are the types of Probability distribution?

# %% [markdown]
# `Ans) Types of probability distributions:`
#
#     (i) Normal/Gaussian Distribution (pdf) --> Continuous Random Variable
#
#     (ii) Bernoulli Distribution (pmf) --> Discrete Random Variable
#
#     (iii) Uniform Distribution (pmf) --> Discrete Random Variable
#
#     (iv) Poisson Distribution (pmf) --> Discrete Random Variable
#
#     (v) Log-Normal Distribution (pdf) --> Continuous Random Variable
#
#     (vi) Binomial Distribution (pmf) --> Discrete Random Variable

# %% [markdown]
# ### Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

# %% [markdown]
# `Ans) The probability density function (pdf) for Normal Distribution:`

# %% [markdown]
# ![6e3mz52e.bmp](attachment:fb122a6d-a7d0-4f59-816e-b42d04a16387.bmp)

# %%
import math
def normpdf(x, mean, std):
    var = float(std)**2
    denom = (2*math.pi*var)**.5
    numer = math.exp(-(float(x)-float(mean))**2/(2*var))
    return numer/denom

# %%
normpdf(3,2,1.5)
# Out:
# 0.2129653370149015

# %% [markdown]
# ### Q4. What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

# %% [markdown]
# `Ans) The properties of the binomial distribution are:`
#
# - There are only two distinct possible outcomes: true/false, success/failure, yes/no.
# - There is a fixed number of 'n' times repeated trials in a given experiment.
# - The probability of success or failure remains constant for each attempt/trial.
# - Only the successful attempts are calculated out of 'n' independent trials.
# - Every trial is an independent trial on its own, this means that the outcome of one trial has no effect on the outcome of another trial.
#
# ### Examples of Binomial Distribution:
#
# #### 1. Testing a Drug:
#
# **The binomial distribution is prominently used in the field of drugs and medicine. Whenever a new drug is invented to cure a particular disease, the effectiveness of the drug can be represented by two outcomes, i.e., whether the drug cures the disease or it does not. Also, the side effects of the drug can be measured in a similar manner. Either the drug causes side effects or it does not. Since the experiment has two possible results, i.e., success and failure, it can be represented with the help of binomial distribution.**
#
# #### 2. Number of Spam Emails Received:
#
# **The prediction of the number of spam emails received by a person is one of the prominent examples of a binomial distribution. This is because an email has two possibilities, i.e., either it can be a spam e-mail or not.**

# %% [markdown]
# ### Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib.

# %%
##First methos using numpy library
import numpy as np
import matplotlib.pyplot as plt

## Generate a random sample size of 1000 
n=1000 #sample size
p=0.4 #probability of success

sample = np.random.binomial(n,p,size=1000)

##Plot a histogram of the results using Fredman diaconis rule i.e. bins='fd'
plt.hist(sample, bins='fd', density=True, edgecolor='black')
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution (n=100, p=0.4)')
plt.show()

# %%
##Second method using scipy library
from scipy.stats import binom
import matplotlib.pyplot as plt

n = 1000
p =0.4

r_values = list(range(n+1))

dist = [binom.pmf(r,n,p) for r in r_values]

plt.bar(r_values,dist)
plt.show()

# %% [markdown]
# ### Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution with given mean at a given point.

# %%
import math

def poisson_cdf(mean, point):
    '''Calculate the cumulative distribution function (cdf) of a Poisson distribution'''
    cdf = 0.0
    for k in range (point +1):
        cdf += math.exp(-mean) * (mean**k) / math.factorial(k)
    return cdf

poisson_cdf(4,2)
# Out:
# 0.2381033055535443

# %%
## Using scipy library
from scipy.stats import poisson
prob = poisson.cdf(2,4)
prob
# Out:
# 0.23810330555354436

# %% [markdown]
# ### Q7. How Binomial distribution different from Poisson distribution?

# %% [markdown]
# ### Ans)
# | Basis for Comparison    |	 Binomial Distribution	  |    Poisson Distribution
# |:-------------------:|:--------------------------------|:------------------------------|
# | Meaning | Binomial distribution is one in which the probability of repeated number of trials are studied. |	Poisson Distribution gives the count of independent events occur randomly with a given period of time. |
# | Nature | Biparametric | Uniparametric |
# | Number of trials | Fixed | Infinite |
# | Success	| Constant probability | Infinitesimal chance of success |
# | Outcomes | Only two possible outcomes, i.e. success or failure.	| Unlimited number of possible outcomes. |
# | Mean and Variance | Mean > Variance	| Mean = Variance |
# | Example	| Coin tossing experiment. | Printing mistakes/page of a large book. |

# %% [markdown]
# ### Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance.

# %%
from scipy.stats import poisson
import numpy as np

#generate random sample from Poisson distribution with mean=5 and sample size=1000
sample = poisson.rvs(mu=5, size=1000)

# Calculate the sample mean and variance
sample_mean = np.mean(sample)
sample_var = np.var(sample)

# Printing the output
print("Poission Sample Mean     :", sample_mean)
print("Poission Sample Variance :", sample_var)
# Out:
# Poission Sample Mean     : 4.884
# Poission Sample Variance : 4.486544000000001

# %% [markdown]
# ### Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# #### Ans) Binomial Distribution:
# For a binomial distribution, having n trials, probability of success be p , probability of failure be q , then
#
# Mean =np-------(1)
#
# variance=npq
#
# Variance=(np)q
#
# Or variance = mean × q
#
# Thus , mean>variance
#
# For example, an event has a probability of success =0.25, there are 10 trials.
#
# N=10
#
# P=0.25
#
# q=(1–0.25)=0.75
#
# Mean =no=10×0.25=2.5
#
# Variance =npq =10×0.25×0.75=1.875
#
# Thus, mean is greater than variance in a binomial distribution.
#
# #### Poisson Distribution:
#
# The mean and the variance of the Poisson distribution are the same, which is equal to the average number of successes that occur in the given interval of time.

# %% [markdown]
# ### Q10. In normal distribution with respect to mean position, where does the least frequent data appear?

# %% [markdown]
# `Ans) In normal distribution with respect to mean position, the data become less frequent when farther away from the mean, which appears in the tails of the distribution. This is because the normal distribution is a symmetric distribution, with a peak at the mean and decreasing density as we move away from the mean in either direction.`
